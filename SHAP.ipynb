# %% [markdown]
# SHAP for Drought or Flood indices

# %%
y_pred=best.predict(X_test_scaled)
drought_thresh = np.percentile(y_pred,10)
flood_thresh = np.percentile(y_pred,90)

# find the indices where the predicted values are below the drought threshold
drought_indices = np.where(y_pred < drought_thresh)[0]
# find the indices where the predicted values are above the flood threshold
flood_indices = np.where(y_pred > flood_thresh)[0]

# %%
drought_indices
# Out:
# array([13, 18, 25])

# %%
import shap
import matplotlib.pyplot as plt
explainer = shap.Explainer(best.predict, X_test_scaled[extr_indices],feature_names=X_test.columns)
shap_values = explainer(X_test_scaled[extr_indices])
for idx in range(len(extr_indices)):
    plt.figure()
    shap.plots.waterfall(shap_values[idx], show=False)

    plt.tight_layout()
    plt.show()

plt.figure()
shap.summary_plot(shap_values, X_test_scaled[extr_indices], show=False)
plt.title('SHAP Summary Plot for Test Data')
plt.tight_layout()
plt.show()
